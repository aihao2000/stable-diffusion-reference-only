# %%
from anime_segmentation import get_model, character_segment
import cv2
from PIL import Image

# %%
model = get_model(
    model_path="/home/aihao/workspace/DeepLearningContent/models/anime-seg/isnetis.ckpt"
)

# %%
img = cv2.cvtColor(
    cv2.imread(
        "/home/aihao/workspace/StableDiffusionReferenceOnly/validation_images/9/1_origin.png",
        cv2.IMREAD_COLOR,
    ),
    cv2.COLOR_BGR2RGB,
)
img = character_segment(model, img)
Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=512x512>
